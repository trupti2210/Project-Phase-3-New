# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Import Datasets

# %%
data=pd.read_csv('Zomato Data.csv',encoding='latin1')

# %%
data
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.shape
# Out:
# (9551, 21)

# %%
data_country=pd.read_excel('Country-Code.xlsx')

# %%
data_country
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
data1=pd.merge(data,data_country,on='Country Code',how='left')

# %%
data1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data1.shape
# Out:
# (9551, 22)

# %% [markdown]
# # Checking Unique values

# %%
data1.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %% [markdown]
# # EDA

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
# visualization of null values in data set

sns.heatmap(data1.isnull())
# Out:
# <AxesSubplot:>

# %%
# Univariate Analysis

# %%
sns.countplot('Country Code', data=data)
# Out:
# <AxesSubplot:xlabel='Country Code', ylabel='count'>

# %% [markdown]
# Those having country code 1 having more views

# %%
sns.countplot(x='Price range',data=data)
plt.show()

# %%
sns.countplot(y='Currency',data=data)
plt.show()

# %% [markdown]
# Indian rupees is mostly used currency, it means zomato has main business in India.
# Remaining all has no such used

# %%
sns.countplot(x='Has Table booking',data=data)
plt.show()

# %%
sns.countplot(x='Has Online delivery',data=data)
plt.show()

# %% [markdown]
# Most of the places have noo online dilevery option

# %%
a=data1[data1['Has Online delivery']=='yes'].Country.value_counts()

# %%
a.plot.pie(autopct='%1.1f%%')
plt.title('Country has online delivry')
plt.show()

# %%
sns.countplot(x='Is delivering now',data=data)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Aggregate rating', data=data)
plt.show()

# %% [markdown]
# Most of the customers has gives 0 aggregates ratings than other
# 3.1 and 3.2 has maximum rating given by customer

# %%
sns.countplot(x='Rating color', data=data)
plt.show()

# %% [markdown]
# orange is most used color for rating.
# Red color is less used color for rating

# %%
sns.countplot(x='Rating text', data=data)
plt.show()

# %%
city_values=data.City.value_counts().values
city_label=data.City.value_counts().index

# %%
plt.pie(city_values[:5],labels=city_labels[:5],autopct='%1.2f%%')
plt.show()

# %%
# find top 10 Cuisine
cuisine_val=data1.Cuisines.value_counts().values
cuisin_label=data1.Cuisines.value_counts().index

# %%
plt.pie(cuisine_val[:10],labels=cuisin_label[:10],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# 26.58 % customers like to eat North Indian Food

# %%
# Find top 10 Locations
val=data1.Locality.value_counts().values
label=data1.Locality.value_counts().index

# %%
plt.pie(val[:10],labels=label[:10],autopct='%1.2f%%')
plt.show()

# %% [markdown]
# Canught place is the top among the all served places

# %%
sns.distplot(data1['Average Cost for two'])
plt.show()

# %% [markdown]
# 50% of restaurents are affordable

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(15,6))
df_good=data1.sort_values(by='Average Cost for two',ascending=False)
sns.barplot(x="Country",y='Average Cost for two',data=df_good)
plt.show()

# %% [markdown]
# Indonasia has a high cost for two

# %%
plt.figure(figsize=(15,6))
df_good=data1.sort_values(by='Average Cost for two',ascending=False).iloc[0:10]
sns.barplot(x="Restaurant Name",y='Average Cost for two',data=df_good)
plt.show()

# %% [markdown]
# Satoo hotel has highaverage cost followed by Skye

# %%
plt.figure(figsize=(15,6))
df_good=data1.sort_values(by='Average Cost for two',ascending=False).iloc[0:10]
sns.barplot(x="City",y='Average Cost for two',data=df_good)
plt.show()

# %% [markdown]
# These are top cities where average cost for two

# %%
sns.boxplot(x='Has Online delivery', y='Votes',data=data)
plt.title('Has online delivery Vs Votes')
plt.show()

# %%
data.groupby('Restaurant Name')['Aggregate rating'].mean().nlargest(10).plot.bar()
plt.show()

# %%
sns.boxplot(x='Has Online delivery', y='Average Cost for two',data=data)
plt.title('Has online delivery Vs Average Cost for two')
plt.show()

# %%
data.groupby('Restaurant Name')['Votes'].mean().nlargest().plot.bar()
# Out:
# <AxesSubplot:xlabel='Restaurant Name'>

# %% [markdown]
# can observe top 10 restaurent on the bais of customer ratings

# %%
sns.scatterplot(x='Average Cost for two', y='Longitude',data=data)

plt.show()

# %%
rating=data1.groupby(['Aggregate rating','Rating color','Rating text']).size().reset_index().rename(columns={0:'Rating count'})

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating count', data=rating)
plt.show()

# %% [markdown]
# When rating betwen 4.5 to 4.9 = > Excellent
# When rating betwen 4.0 to 3.4 = >Very good
# When rating betwen 3.5 to 3.9 = > Good
# When rating betwen 2.5 to 2.9 = > Average

# %%
plt.figure(figsize=(15,6))
df_good=data1.sort_values(by='Latitude',ascending=False).iloc[0:10,:]
sns.barplot(x="Restaurant Name",y='Latitude',data=df_good)
plt.show()

# %%
sns.barplot(x='Price range',y='Average Cost for two', data=data)
plt.show()

# %% [markdown]
# Many restaurant having price range 3

# %%
sns.barplot(x='Rating text',y='Average Cost for two', data=data)
plt.show()

# %% [markdown]
# THose restaurent having rating Excellent having highest average cost for two

# %%
plt.figure(figsize=(12,6))
sns.barplot(x="Aggregate rating",y='Rating text',data=rating)
plt.show()

# %% [markdown]
# Many restaurent having rating Execellent, and their aggregate rating is also high it mean more than 4.5

# %%
sns.scatterplot(x='Votes',y='Average Cost for two',data=data)
plt.show()

# %% [markdown]
# Votes have no liner relationship with Avg. Cost for Two

# %%
sns.scatterplot(x='Votes',y='Aggregate rating',data=data)
plt.show()

# %% [markdown]
# There is no direct relationships between each other

# %% [markdown]
# # Multi Variate Analysis

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x="Aggregate rating",y='Average Cost for two',hue='Has Online delivery',data=data)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Aggregate rating',y='Rating count',hue='Rating color',data=rating, palette=['blue','red','orange','yellow','green','darkgreen'])
plt.show()

# %%
plt.figure(figsize=(15,5)
sns.boxplot(x='Country', y='Average Cost for two',hue='Has Online delivery',data=data)
plt.show()
# Out:
#   File "C:\Users\Shree\AppData\Local\Temp\ipykernel_3048\2710203362.py", line 2
#     sns.boxplot(x='Country', y='Average Cost for two',hue='Has Online delivery',data=data)
#     ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x="Average Cost for two", y='Aggregate rating',hue='Price range',data=data)
plt.xlabel("Average Cost for two")
plt.ylabel("Aggregate rating")
plt.title("Rating vs Cost of Two")
plt.show()

# %%
sns.scatterplot(x='Votes',y='Aggregate rating',hue='Has Online delivery',data=data)
plt.show()

# %% [markdown]
# # Encoding DataFrame

# %%
data.drop(columns=['Restaurant ID','Locality Verbose'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for col in data[data.columns[data.dtypes == 'object']]:
                data[col]=le.fit_transform(data[col])

# %%
data.head()
# Out:
#    Restaurant Name  Country Code  City  Address  Locality   Longitude  \
# 0             3749           162    73     8685       171  121.027535
# 1             3173           162    73     6055       593  121.014101
# 2             2897           162    75     4684       308  121.056831
# 3             4707           162    75     8690       862  121.056475
# 4             5523           162    75     8689       862  121.057508
#
#     Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0  14.565443       920                  1100         0                  1
# 1  14.553708      1111                  1200         0                  1
# 2  14.581404      1671                  4000         0                  1
# 3  14.585318      1126                  1500         0                  0
# 4  14.584450      1122                  1500         0                  1
#
#    Has Online delivery  Is delivering now  Switch to order menu  Price range  \
# ...

# %% [markdown]
# # Describe Dataset

# %%
data.describe()
# Out:
#        Restaurant Name  Country Code         City      Address     Locality  \
# count      9551.000000   9551.000000  9551.000000  9551.000000  9551.000000
# mean       3653.204586     18.365616    78.301434  4542.439430   658.128468
# std        2142.917876     56.750546    23.198915  2565.717005   315.866515
# min           0.000000      1.000000     0.000000     0.000000     0.000000
# 25%        1777.500000      1.000000    76.000000  2323.500000   381.000000
# 50%        3595.000000      1.000000    88.000000  4610.000000   696.000000
# 75%        5485.500000      1.000000    88.000000  6746.500000   921.000000
# max        7445.000000    216.000000   140.000000  8917.000000  1207.000000
#
#          Longitude     Latitude    Cuisines  Average Cost for two  \
# count  9551.000000  9551.000000  9551.00000           9551.000000
# mean     64.126574    25.854381   989.95079           1199.210763
# std      41.467058    11.007935   514.72354          16121.183073
# ...

# %% [markdown]
# # Corrrelation of Feature with Target Columns

# %%
data.corr()['Average Cost for two'].sort_values()
# Out:
# Latitude               -0.111088
# Rating color           -0.049970
# City                   -0.028838
# Has Online delivery    -0.018974
# Locality               -0.012136
# Is delivering now      -0.001862
# Cuisines                0.005755
# Has Table booking       0.007758
# Restaurant Name         0.019241
# Address                 0.022749
# Rating text             0.031439
# Country Code            0.043225
# Currency                0.045615
# Longitude               0.045891
# Aggregate rating        0.051792
# Votes                   0.067783
# Price range             0.075083
# Average Cost for two    1.000000
# Switch to order menu         NaN
# Name: Average Cost for two, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(),annot=True, fmt='.2f')
plt.show()

# %% [markdown]
# price range has 8% positive correlation with target column
# vote has 7% correlation with target column

# %% [markdown]
# # Visualization of correlation of feature columns with label columns

# %%
plt.figure(figsize=(20,8))
data1.corr()['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar',color='c')
plt.xlabel("Features",fontsize=15)
plt.ylabel("Average Cost for two",fontsize=15)
plt.title("Correlation",fontsize=18)
plt.show()

# %% [markdown]
# price rate, votes and Aggregate rating having highest correlation with avg. cost for two

# %% [markdown]
# # Checking distribution of Data

# %%
data.shape
# Out:
# (9551, 21)

# %%
plt.figure(figsize=(25,30))
plotnumber=1

for column in data:
    if plotnumber <=20:
            ax=plt.subplot(5,4,plotnumber)
            sns.distplot(data[column])
            plt.xlabel(column,fontsize=20)
    plotnumber  +=1
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\272624333.py in <module>
#       5     if plotnumber <=20:
#       6             ax=plt.subplot(5,4,plotnumber)
# ----> 7             sns.distplot(data[column])
#       8             plt.xlabel(column,fontsize=20)
#       9     plotnumber  +=1
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2634
#    2635     # Make a a 1-d float array
# -> 2636     a = np.asarray(a, float)
#    2637     if a.ndim > 1:
#    2638         a = a.squeeze()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     870               dtype='datetime64[ns]')
#     871         """
# --> 872         return np.asarray(self._values, dtype)
#     873
# ...

# %%
data.skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# Longitude               -2.807328
# Latitude                -3.081635
# Average Cost for two    35.477915
# Price range              0.889618
# Aggregate rating        -0.954130
# Votes                    8.807637
# dtype: float64

# %% [markdown]
# # Checking Outliers

# %%
plt.figure(figsize=(25,30))
plotnumber=1

for column in data:
    if plotnumber <=20:
            plt.subplot(5,4,plotnumber)
            ax=sns.boxplot(data=data[column])
            plt.xlabel(column,fontsize=20)
    plotnumber  +=1
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\3383048691.py in <module>
#       5     if plotnumber <=20:
#       6             plt.subplot(5,4,plotnumber)
# ----> 7             ax=sns.boxplot(data=data[column])
#       8             plt.xlabel(column,fontsize=20)
#       9     plotnumber  +=1
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2241 ):
#    2242
# -> 2243     plotter = _BoxPlotter(x, y, hue, data, order, hue_order,
# ...

# %% [markdown]
# # Removing Outliers

# %%
data.head(1)
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
#
#                                     Locality  \
# 0  Century City Mall, Poblacion, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
#
#                      Cuisines  Average Cost for two          Currency  \
# 0  French, Japanese, Desserts                  1100  Botswana Pula(P)
#
#   Has Table booking Has Online delivery Is delivering now  \
# 0               Yes                  No                No
#
#   Switch to order menu  Price range  Aggregate rating Rating color  \
# 0                   No            3               4.8   Dark Green
#
#   Rating text  Votes
# 0   Excellent    314

# %%
from scipy.stats import zscore

z_score=zscore(data[['Average Cost for two','Votes']])#only removing outliers from continewous data
abs_z_score=np.abs(z_score)
filtering_entry=(abs_z_score<3).all(axis=1)
df=data[filtering_entry]

# %%
df.shape
# Out:
# (9362, 21)

# %%
data.shape
# Out:
# (9551, 21)

# %% [markdown]
# # Percentage of Data Loss

# %%
data_loss=((9551-9362)/9551*100)
print(data_loss,'%')
# Out:
# 1.978850382158936 %

# %% [markdown]
# # Checking Mulit Colinearlity

# %%
x=df.drop(columns=['Average Cost for two'],axis=1)
y=df['Average Cost for two']

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()
scaled_X = scaler.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\4191268361.py in <module>
#       1 scaler= StandardScaler()
# ----> 2 scaled_X = scaler.fit_transform(x)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
#     808     def partial_fit(self, X, y=None, sample_weight=None):
#
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()

# %%
vif['Features']=x.columns
vif['vif']=[variance_inflation_factor(scaled_x,i) for i in range(scaled_x.shape[1])]
vif
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\4247007290.py in <module>
#       1 vif['Features']=x.columns
# ----> 2 vif['vif']=[variance_inflation_factor(scaled_x,i) for i in range(scaled_x.shape[1])]
#       3 vif
#
# NameError: name 'scaled_x' is not defined

# %% [markdown]
# # Dropping columns which having multicollinearity

# %%
df.drop(columns=['Country Code','Switch to order menu','Country'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\884390679.py in <module>
# ----> 1 df.drop(columns=['Country Code','Switch to order menu','Country'],axis=1,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
df.shape
# Out:
# (9362, 19)

# %%
x=df.drop(columns=['Average Cost for two'],axis=1)
y=df['Average Cost for two']

# %% [markdown]
# # Selecting KBestFeatures

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
bestfeat=SelectKBest(score_func = f_classif, k='all')
fit=bestfeat.fit(x,y)
dfscores=pd.DataFrame(fit.scores_)
dfcolumns=pd.DataFrame(x.columns)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\3219108903.py in <module>
#       1 bestfeat=SelectKBest(score_func = f_classif, k='all')
# ----> 2 fit=bestfeat.fit(x,y)
#       3 dfscores=pd.DataFrame(fit.scores_)
#       4 dfcolumns=pd.DataFrame(x.columns)
#
# ~\anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     395             Returns the instance itself.
#     396         """
# --> 397         X, y = self._validate_data(
#     398             X, y, accept_sparse=["csr", "csc"], multi_output=True
#     399         )
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# ...

# %%
data1.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
x_best=x.drop(columns=['Restaurant Name','Is delivering now']).copy()

# %%
data.skew()
# Out:
# Restaurant ID            0.061570
# Country Code             3.043965
# Longitude               -2.807328
# Latitude                -3.081635
# Average Cost for two    35.477915
# Price range              0.889618
# Aggregate rating        -0.954130
# Votes                    8.807637
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x_best,method='yeo-johnson')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\347646241.py in <module>
#       1 from sklearn.preprocessing import power_transform
# ----> 2 x=power_transform(x_best,method='yeo-johnson')
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in power_transform(X, method, standardize, copy)
#    3422     """
#    3423     pt = PowerTransformer(method=method, standardize=standardize, copy=copy)
# -> 3424     return pt.fit_transform(X)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit_transform(self, X, y)
#    3063             Transformed data.
#    3064         """
# -> 3065         return self._fit(X, y, force_transform=True)
#    3066
#    3067     def _fit(self, X, y=None, force_transform=False):
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in _fit(self, X, y, force_transform)
# ...

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %% [markdown]
# # Linear Regression Model

# %%
maxAccu= 0
maxRS=0

for i in range(1,1000):
    X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.30, random_state=i)
    lr=LinearRegression()
    lr.fit(x_train, y_train)
    pred=lr.predict(X_test)
    r2=r2_score(y_test,pred)
    
    if r2>maxAccu:
        maxAccu=r2
        maxRS=i
print('best R2 score is :', maxAccu,"on random state,",maxRS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\956123428.py in <module>
#       5     X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=.30, random_state=i)
#       6     lr=LinearRegression()
# ----> 7     lr.fit(x_train, y_train)
#       8     pred=lr.predict(X_test)
#       9     r2=r2_score(y_test,pred)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...

# %%
# Splitting data into train Test split

regressors = {
    
                'Linear Regrssion' : LinearRegression(),
}
results=pd.DataFrame(colmuns=['MAE','MSE','RMSE','R2-Score'])

for method, func in regressiors.items():
    model=func.fit(X_train,y_train)
    pred=model.predict(X_test)
    results.loc[method]=[np.round(mean_absolute_error(y_test,pred),3),
                         np.round(mean_squared_error(y_test,pred),3),
                         np.sqrt(mean_squared_error(y_test,pred)),
                         np.round(r2_score(y_test,pred),3)
                        ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\492187348.py in <module>
#       5                 'Linear Regrssion' : LinearRegression(),
#       6 }
# ----> 7 results=pd.DataFrame(colmuns=['MAE','MSE','RMSE','R2-Score'])
#       8
#       9 for method, func in regressiors.items():
#
# TypeError: __init__() got an unexpected keyword argument 'colmuns'

# %% [markdown]
# # Cross Validation of Model

# %%
y_pred=lr.predict(X_Test)
from sklearnmodel_selection import cross_val_score
lss=r2_score(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\124578229.py in <module>
# ----> 1 y_pred=lr.predict(X_Test)
#       2 from sklearnmodel_selection import cross_val_score
#       3 lss=r2_score(y_test,y_pred)
#
# NameError: name 'X_Test' is not defined

# %%
for j in range (4,10):
    isscore=cross_val_score(lr,x,y,cv=j)
    lsc=isscore.mean()
    print('at cv:-',j)
    print('Cross validation score is:-',lsc*100)
    print('Accuracy_socre is: -', lss*100)
    print('\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7416\3228146055.py in <module>
#       1 for j in range (4,10):
# ----> 2     isscore=cross_val_score(lr,x,y,cv=j)
#       3     lsc=isscore.mean()
#       4     print('at cv:-',j)
#       5     print('Cross validation score is:-',lsc*100)
#
# NameError: name 'cross_val_score' is not defined
